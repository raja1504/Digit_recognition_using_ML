# %%
from keras.datasets import mnist
from keras.layers import Conv2D,MaxPooling2D,Dropout,Flatten,Dense
from keras.models import Sequential
(xtrain,ytrain),(xtest,ytest)= mnist.load_data()
from keras.callbacks import EarlyStopping
#xtrain.shape:- used for check size of xtrain
xtrain1=xtrain.reshape(xtrain.shape[0],28,28,1)
xtest1=xtest.reshape(xtest.shape[0],28,28,1)
model=Sequential()
model.add(Conv2D(28,kernel_size=(3,3),input_shape=[28,28,1]))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Flatten())
model.add(Dense(128,activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(10,activation='Softmax'))
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
es=EarlyStopping(monitor='accuracy',min_delta=0.01,patience=3,mode='auto')
hs=model.fit(xtrain,ytrain,callbacks=[es],validation_data=(xtest,ytest),epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 41s 21ms/step - loss: 0.8512 - accuracy: 0.8371 - val_loss: 0.2057 - val_accuracy: 0.9432
# Epoch 2/10
# 1875/1875 [==============================] - 40s 21ms/step - loss: 0.2841 - accuracy: 0.9201 - val_loss: 0.1558 - val_accuracy: 0.9595
# Epoch 3/10
# 1875/1875 [==============================] - 50s 27ms/step - loss: 0.2324 - accuracy: 0.9351 - val_loss: 0.1490 - val_accuracy: 0.9622
# Epoch 4/10
# 1875/1875 [==============================] - 40s 21ms/step - loss: 0.1909 - accuracy: 0.9465 - val_loss: 0.1445 - val_accuracy: 0.9647
# Epoch 5/10
# 1875/1875 [==============================] - 39s 21ms/step - loss: 0.1781 - accuracy: 0.9500 - val_loss: 0.1681 - val_accuracy: 0.9607
# Epoch 6/10
# 1875/1875 [==============================] - 40s 21ms/step - loss: 0.1576 - accuracy: 0.9554 - val_loss: 0.1514 - val_accuracy: 0.9688
# Epoch 7/10
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(hs.history['val_accuracy'])
plt.plot(hs.history['accuracy'])
plt.legend(['val-accuracy','accuracy'])

# %%
plt.plot(hs.history['val_loss'])
plt.plot(hs.history['loss'])
plt.legend(['valloss','training-loss'])
